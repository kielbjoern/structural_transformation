# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ## Table of Contents
# 1. [Dataset Overview](#dataset-overview)
# 2. [Handling Missing Values](#handling-missing-values)
# 3. [Feature Distributions](#feature-distributions)
# 4. [Possible Biases](#possible-biases)
# 5. [Correlations](#correlations)

# %% [markdown]
# . [Correlations](#correlations)

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Dataset Overview
#
# [Provide a high-level overview of the dataset. This should include the source of the dataset, the number of samples, the number of features, and example showing the structure of the dataset.]

# %%
import pandas as pd

# Load the data for Germany
df = pd.read_csv('data germany/ge_gesamt.csv', header=0)

# Number of samples
num_samples = df.shape[0]

# Number of features
num_features = df.shape[1]

# Display these dataset characteristics
print(f"Number of samples: {num_samples}")
print(f"Number of features: {num_features}")

# Display the first few rows of the dataframe to show the structure
print("Example data:")
print(df.head())
print(df.dtypes)
# Out:
# Number of samples: 208
# Number of features: 6
# Example data:
#    year_of_census  1. Sector  2. Sector  3. Sector   delta  age
# 0            1882      0.531      0.282      0.186  0.0092   57
# 1            1882      0.526      0.286      0.189  0.0089   56
# 2            1882      0.520      0.289      0.191  0.0091   55
# 3            1882      0.514      0.293      0.193  0.0093   54
# 4            1882      0.508      0.298      0.194  0.0088   53
# year_of_census      int64
# 1. Sector         float64
# 2. Sector         float64
# 3. Sector         float64
# delta             float64
# age                 int64
# dtype: object

# %% [markdown]
# ## Handling Missing Values
#
# [Identify any missing values in the dataset, and describe your approach to handle them if there are any. If there are no missing values simply indicate that there are none.]

# %%
# I need data for each individual year, not just for the cohorts. 
# Therefore, the missing data needs to be inferred. 
# This should be done using TensorFlow.

# %%
# Handling missing values:
# I will use TensorFlow for the interpolation of the missing data - in a separate program.

# %% [markdown]
# ## Feature Distributions
#
# [Plot the distribution of various features and target variables. Comment on the skewness, outliers, or any other observations.]

# %%
# Example: Plotting histograms of all numerical features
df.hist(figsize=(12, 12))
plt.show()

# %% [markdown]
# ## Possible Biases
#
# [Investigate the dataset for any biases that could affect the model’s performance and fairness (e.g., class imbalance, historical biases).]

# %%
# There is no bias. I have historical data.

# %% [markdown]
# ## Correlations
#
# [Explore correlations between features and the target variable, as well as among features themselves.]

# %%
# Example: Plotting a heatmap to show feature correlations
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
# Define target variable and input features
target = 'delta'
features = [col for col in df.columns if col != target]

# Compute correlations with "delta"
correlations = df.corr(numeric_only=True)[target].drop(target)

# Convert to DataFrame and sort
correlation_df = correlations.to_frame(name='Correlation Coefficient').sort_values(by='Correlation Coefficient', ascending=False)

# Create bar plot
plt.figure(figsize=(8, 5))
sns.barplot(x=correlation_df['Correlation Coefficient'], y=correlation_df.index, palette='coolwarm')
plt.title('Influence of Other Variables on "delta" (Correlation Analysis)')
plt.xlabel('Correlation with delta')
plt.ylabel('Variable')
plt.grid(True)
plt.tight_layout()
plt.show()

correlation_df.round(3)
# Out:
# C:\Users\bjoer\AppData\Local\Temp\ipykernel_19024\548026449.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation_df['Correlation Coefficient'], y=correlation_df.index, palette='coolwarm')
#                 Correlation Coefficient
# 1. Sector                         0.224
# age                               0.190
# year_of_census                    0.083
# 3. Sector                        -0.142
# 2. Sector                        -0.240

# %%
# Load the data for SG
df_sh = pd.read_csv('data sh/sh_gesamt.csv', header=0)

# Number of samples
num_samples = df_sh.shape[0]

# Number of features
num_features = df_sh.shape[1]

# Display these dataset characteristics
print(f"Number of samples: {num_samples}")
print(f"Number of features: {num_features}")

# Display the first few rows of the dataframe to show the structure
print("Example data:")
print(df_sh.head())
print(df_sh.dtypes)
# Out:
# Number of samples: 208
# Number of features: 6
# Example data:
#    year_of_census  1. Sector  2. Sector  3. Sector   delta  age
# 0            1882      0.500      0.274      0.226  0.0031   57
# 1            1882      0.491      0.280      0.229  0.0038   56
# 2            1882      0.483      0.286      0.231  0.0049   55
# 3            1882      0.480      0.288      0.232  0.0053   54
# 4            1882      0.477      0.290      0.233  0.0057   53
# year_of_census      int64
# 1. Sector         float64
# 2. Sector         float64
# 3. Sector         float64
# delta             float64
# age                 int64
# dtype: object

# %%
# Example: Plotting histograms of all numerical features
df_sh.hist(figsize=(12, 12))
plt.show()

# %%
# Example: Plotting a heatmap to show feature correlations
correlation_matrix = df_sh.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
# Define target variable and input features
target = 'delta'
features = [col for col in df_sh.columns if col != target]

# Compute correlations with "delta"
correlations = df_sh.corr(numeric_only=True)[target].drop(target)

# Convert to DataFrame and sort
correlation_df_sh = correlations.to_frame(name='Correlation Coefficient').sort_values(by='Correlation Coefficient', ascending=False)

# Create bar plot
plt.figure(figsize=(8, 5))
sns.barplot(x=correlation_df_sh['Correlation Coefficient'], y=correlation_df_sh.index, palette='coolwarm')
plt.title('Influence of Other Variables on "delta" (Correlation Analysis)')
plt.xlabel('Correlation with delta')
plt.ylabel('Variable')
plt.grid(True)
plt.tight_layout()
plt.show()

correlation_df.round(3)
# Out:
# C:\Users\bjoer\AppData\Local\Temp\ipykernel_19024\819806219.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation_df_sh['Correlation Coefficient'], y=correlation_df_sh.index, palette='coolwarm')
#                 Correlation Coefficient
# 1. Sector                         0.224
# age                               0.190
# year_of_census                    0.083
# 3. Sector                        -0.142
# 2. Sector                        -0.240
